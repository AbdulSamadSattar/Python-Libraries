# %% [markdown]
# # 🎙️ Speech Recognition Using Python
#
# ## 📌 Introduction
#
# Speech Recognition is a technology that enables computers to **understand and convert human speech into text**. In this project, we will build a simple Speech Recognition system using Python and its speech-processing libraries.
#
# The system will capture audio through a microphone, process the spoken words, and convert them into readable text. This project provides a practical introduction to **audio processing, speech recognition, Python libraries, and human-computer interaction**.
#
# ## 🎯 Objectives
#
# - Capture speech through a microphone.
# - Convert spoken words into text.
# - Learn how Python libraries can process audio input.
# - Handle common speech-recognition errors and exceptions.
# - Build a foundation for more advanced voice-controlled applications.
#
# ## 🛠️ Technologies & Libraries
#
# - **Python**
# - **SpeechRecognition** – for converting speech into text.
# - **PyAudio** – for capturing audio from the microphone.
#
# ## 🚀 Project Outcome
#
# By completing this project, we will understand the basic workflow of a speech recognition system:
#
# **Microphone → Audio Input → Speech Processing → Text Output**
#
# This project can later be extended to create applications such as **voice assistants, voice-controlled programs, automated transcription systems, and AI-based conversational applications**.

# %%
pip install SpeechRecognition pyttsx3 wikipedia
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pyaudio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pywin32 
# to elminiate ModuleNotFoundError: No module named 'pywintypes'Cell
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr
import pyttsx3
import wikipedia

engine = pyttsx3.init()

def speak(text):
    engine.say(text)
    engine.runAndWait()

recognizer = sr.Recognizer()

with sr.Microphone() as source:
    print("Listening...")
    audio = recognizer.listen(source)

try:
    command = recognizer.recognize_google(audio)
    print("You said", command)

    results = wikipedia.summary(command, sentences=2)
    print(results)

    speak(results)

except:
    print("Sorry, I could not understand the audio.")
    speak("Sorry, I could not understand the audio.")
# Out:
# Listening...
# You said capital of Pakistan
# Sorry, I could not understand the audio.
