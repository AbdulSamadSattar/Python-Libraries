# %% [markdown]
# Markdown
# # Seaborn: Quick Overview
#
# **Seaborn** is a Python data visualization library built on top of Matplotlib. It provides a high-level interface for drawing attractive, informative, and statistical graphics.
#
# ---
#
# ### Key Features
# * **Built-in Themes:** Comes with polished default styles and color palettes.
# * **Dataset-Oriented:** Integrates directly with `Pandas` DataFrames.
# * **Statistical Plotting:** Simplifies complex visualizations like heatmaps, pair plots, and regression lines.
# * **Matplotlib Backed:** Allows full customization using standard Matplotlib commands.
#
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
var1 = [1,2,3,4,5]
var2 = [5,4,3,2,1]
sns.lineplot(x=var1, y=var2)
plt.title("Line Plot using Seaborn")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
df1 = sns.load_dataset('penguins')
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=df1)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=df1, hue = 'sex')
plt.show()

# %%
# sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=df1, hue = 'sex', markers = ['o','>'])
sns.lineplot(
    x='bill_length_mm',
    y='flipper_length_mm',
    data=df1,
    hue='sex',
    style='sex', # use with markers
    palette= ['blue', 'red'],
    markers=['o', '>']  
)
plt.show()

# %%
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df1['island']
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 3      Torgersen
# 4      Torgersen
#          ...
# 339       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: island, Length: 344, dtype: str

# %%
sns.barplot(x = df1.island, y = df1.bill_length_mm)
plt.show()

# %%
sns.barplot(x = 'island', y = 'bill_length_mm', data = df1, hue = 'sex', palette = 'prism')
plt.show()

# %%
sns.barplot(x = 'island', y = 'bill_length_mm', data = df1, hue = 'sex', palette = 'gist_rainbow')
plt.show()

# %%
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.displot(df1['flipper_length_mm'])
plt.show()

# %%
sns.displot(df1['flipper_length_mm'],bins = [170,180,190,200,210,220,230,240])
plt.show()

# %%
sns.displot(df1['flipper_length_mm'],bins = [170,180,190,200,210,220,230,240],color = 'red' )
plt.show()

# %%
sns.displot(df1['flipper_length_mm'],bins = [170,180,190,200,210,220,230,240],color = 'red' , kde = True)
plt.show()

# %%
# %who_ls
# Out:
# ['df1', 'plt', 'sns', 'var1', 'var2']

# %%
# %who
# Out:
# df1	 plt	 sns	 var1	 var2

# %%
# %whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# df1        DataFrame    Shape: (344, 7)
# plt        module       <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# sns        module       <module 'seaborn' from 'd<...>s\\seaborn\\__init__.py'>
# var1       list         n=5
# var2       list         n=5
