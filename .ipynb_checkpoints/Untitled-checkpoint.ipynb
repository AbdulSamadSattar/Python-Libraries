# %%
import numpy as np

# %%
import time

# %%
size = 100000

# %%
list1 = list(range(size))
list2 = list(range(size))

# %%
arr1 = np.array(list1)
arr2 = np.array(list2)

# %%
start = time.time()
result_list = []
for i in range (size):
    result_list.append(list1[i]+list2[i])
end = time.time()
print("List time: ", end - start)
# Out:
# List time:  0.06673669815063477

# %%
start = time.time()
result_array = arr1 +arr2

end = time.time()
print("Numpy time: ", end - start)
# Out:
# Numpy time:  0.006983280181884766

# %%
print(np.__version__)
# Out:
# 2.4.2
